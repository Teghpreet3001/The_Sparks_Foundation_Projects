# %% [markdown]
# # The Sparks Foundation
# ### GRIP Septemer 2021 Batch
# ### Author: Teghpreet Singh Mago
# ### Task 3 : Perform ‘Exploratory Data Analysis’ on dataset ‘Global Terrorism’

# %% [markdown]
# ### 1. Problem defintion
# As a security/defense analyst, try to find out the hot zone of terrorism.
# What all security issues and insights you can derive by EDA?
# ### 2. Dataset Source
# Data can be found at https://bit.ly/2TK5Xn5
# ### 3. Evaluation
# If we can reach 95% accuracy at predicting, we'll be successful at the project.
# ### 4. Libraries and Features
# For this project, we will import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns, warnings, sklearn and sklearn.ensemble from RandomForestRegressor

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing Data in the form of CSV Files

# %%
df= pd.read_csv(r'C:\Users\HP\Desktop\globalterrorismdb_0718dist.csv',encoding='latin1')
print(df.shape)
# Out:
# (181691, 135)

# %%
df.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
# 5  1.970010e+11   1970       1     1        NaN         0        NaN      217
# 6  1.970010e+11   1970       1     2        NaN         0        NaN      218
# 7  1.970010e+11   1970       1     2        NaN         0        NaN      217
# 8  1.970010e+11   1970       1     2        NaN         0        NaN      217
# 9  1.970010e+11   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
df.tail(10)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181681  2.017120e+11   2017      12    31        NaN         0        NaN
# 181682  2.017120e+11   2017      12    31        NaN         0        NaN
# 181683  2.017120e+11   2017      12    31        NaN         0        NaN
# 181684  2.017120e+11   2017      12    31        NaN         0        NaN
# 181685  2.017120e+11   2017      12    31        NaN         0        NaN
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ...  \
# 181681      160  Philippines       5  ...
# 181682       98        Italy       8  ...
# ...

# %%
df.describe().T
# Out:
#               count          mean           std           min           25%  \
# eventid    181691.0  2.002704e+11  1.325955e+09  1.970000e+11  1.991020e+11
# iyear      181691.0  2.002639e+03  1.325943e+01  1.970000e+03  1.991000e+03
# imonth     181691.0  6.467277e+00  3.388303e+00  0.000000e+00  4.000000e+00
# iday       181691.0  1.550564e+01  8.814045e+00  0.000000e+00  8.000000e+00
# extended   181691.0  4.534622e-02  2.080629e-01  0.000000e+00  0.000000e+00
# ...             ...           ...           ...           ...           ...
# nreleased   10400.0 -2.901827e+01  6.572012e+01 -9.900000e+01 -9.900000e+01
# INT_LOG    181691.0 -4.543731e+00  4.543547e+00 -9.000000e+00 -9.000000e+00
# INT_IDEO   181691.0 -4.464398e+00  4.637152e+00 -9.000000e+00 -9.000000e+00
# INT_MISC   181691.0  9.000996e-02  5.684573e-01 -9.000000e+00  0.000000e+00
# INT_ANY    181691.0 -3.945952e+00  4.691325e+00 -9.000000e+00 -9.000000e+00
#
#                     50%           75%           max
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# ## Changing Column Names and Extracting Important Columns

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':"Day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'Latitude',
    'longitude':'Longitude','summary':'Summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'Kill',
     'nwound':'Wound'},inplace=True)

# %%
df = df[['Year','Month','Day','Country','State','Region','City','Latitude','Longitude',"Attacktype",'Kill',
               'Wound','target1','Summary','Group','Targettype','Weapon','motive']]

df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      Attacktype  Kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   NaN
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   NaN
#
# ...

# %%
df['Wound'] = df['Wound'].fillna(0)
df['Kill'] = df['Kill'].fillna(0)
df['Casualities'] = df['Kill'] + df['Wound']

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   City         181257 non-null  object
#  7   Latitude     177135 non-null  float64
#  8   Longitude    177134 non-null  float64
#  9   Attacktype   181691 non-null  object
#  10  Kill         181691 non-null  float64
#  11  Wound        181691 non-null  float64
#  12  target1      181055 non-null  object
#  13  Summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Targettype   181691 non-null  object
#  16  Weapon       181691 non-null  object
#  17  motive       50561 non-null   object
# ...

# %%
df['Casualities'].count()
# Out:
# 181691

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude           Kill          Wound    Casualities
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# ## Data Correction

# %%
df.corr()
# Out:
#                  Year     Month       Day  Latitude  Longitude      Kill  \
# Year         1.000000  0.000139  0.018254  0.166933   0.003917  0.021252
# Month        0.000139  1.000000  0.005497 -0.015978  -0.003880  0.004031
# Day          0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003225
# Latitude     0.166933 -0.015978  0.003423  1.000000   0.001463 -0.013170
# Longitude    0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000587
# Kill         0.021252  0.004031 -0.003225 -0.013170  -0.000587  1.000000
# Wound        0.017484  0.003178 -0.001082  0.015920   0.000205  0.443326
# Casualities  0.020675  0.003805 -0.001808  0.009899   0.000013  0.651885
#
#                 Wound  Casualities
# Year         0.017484     0.020675
# Month        0.003178     0.003805
# Day         -0.001082    -0.001808
# Latitude     0.015920     0.009899
# Longitude    0.000205     0.000013
# Kill         0.443326     0.651885
# Wound        1.000000     0.968724
# ...

# %% [markdown]
# ##  Data Visualisation through Matplotlib and Seaborn

# %%
x = df['Year'].unique()
y = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x, y, palette='pastel')
plt.xticks(rotation = 45)
plt.xlabel('Attack Year',fontsize=15)
plt.ylabel('Number of Attacks each year',fontsize=15)
plt.title('Number of Attacks V/S Years',fontsize=20)
plt.grid(False)
plt.show()

# %%
Region = df['Region'].unique()
df1 = df.groupby(['Region'])
x = df1['Region'].count()
print(x)
# Out:
# Region
# Australasia & Oceania            282
# Central America & Caribbean    10344
# Central Asia                     563
# East Asia                        802
# Eastern Europe                  5144
# Middle East & North Africa     50474
# North America                   3456
# South America                  18978
# South Asia                     44974
# Southeast Asia                 12485
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Name: Region, dtype: int64

# %%
e = np.full(x.shape, 0.05)
c = ['pink','red','orange','gold','yellow','green','teal','cyan', 'skyblue', 'blue','purple','magenta']
plt.figure(figsize = (18,10))
plt.pie(x, labels = Region, autopct='%1.0f%%', explode=e, colors=c)
plt.legend(loc='lower left')
plt.title('Terrorism Rate categorised by Regions', fontsize=20)
plt.show()

# %%
X = df['Country'].unique()
df1 = df.groupby(['Country'])
Y = df1['Country'].count().sort_values()

plt.subplots(figsize=(15,6))
sns.barplot(X[0:60],Y[0:60])
plt.title('Top Countries Affected by Terrorism (First 60)',fontsize=20)
plt.xlabel('Countries',fontsize=15)
plt.ylabel('Number of attacks',fontsize=15)
plt.xticks(rotation= 90, fontsize=10)
plt.show()

plt.subplots(figsize=(15,6))
sns.barplot(X[60:120],Y[60:120])
plt.title('Top Countries Affected by Terrorism (Next 60)',fontsize=20)
plt.xlabel('Countries',fontsize=15)
plt.ylabel('Number of attacks',fontsize=15)
plt.xticks(rotation= 90, fontsize=10)
plt.show()

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year', fontsize=20)
plt.ylabel('Number of Attacks', fontsize=15)
plt.ylabel('Year of Attack', fontsize=15)
plt.grid(True)
plt.show()

# %%
Weapon_data = df['Weapon'].value_counts()
print(Weapon_data)
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# ...

# %%
plt.figure(figsize= (18,10))
plt.barh(Weapon_data.index, Weapon_data.values)
plt.title('Most Used Weapon Type',fontsize=20)
plt.xlabel('Weapon Type',fontsize=15)
plt.ylabel('Attacks count',fontsize=15)
plt.grid(True)
plt.show()

# %%
City = df['City'].value_counts().drop('Unknown').head(20)
print(City)
# Out:
# Baghdad           7589
# Karachi           2652
# Lima              2359
# Mosul             2265
# Belfast           2171
# Santiago          1621
# Mogadishu         1581
# San Salvador      1558
# Istanbul          1048
# Athens            1019
# Bogota             984
# Kirkuk             925
# Beirut             918
# Medellin           848
# Benghazi           840
# Peshawar           819
# Quetta             803
# Guatemala City     755
# Baqubah            745
# Kabul              738
# Name: City, dtype: int64

# %%
plt.figure(figsize=(18,10))
sns.barplot(x=City.index, y=City.values, palette='spring')
plt.xticks(rotation = 50,fontsize=12.5)
plt.xlabel("City",fontsize=15)
plt.ylabel("Number of attacks",fontsize=15)
plt.title("Top 20 Most Effected Cities",fontsize=20)
plt.show()

# %%
terrorist_group = df['Group'].value_counts().drop('Unknown').head(20)
print(terrorist_group)
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Basque Fatherland and Freedom (ETA)                 2024
# Communist Party of India - Maoist (CPI-Maoist)      1878
# Maoists                                             1630
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# National Liberation Army of Colombia (ELN)          1561
# Tehrik-i-Taliban Pakistan (TTP)                     1351
# ...

# %%
plt.figure(figsize=(18,10))
sns.barplot(x=terrorist_group.index, y=terrorist_group.values, palette='Oranges')
plt.xticks(rotation = 90,fontsize=12.5)
plt.xlabel("Terrorist Group",fontsize=15)
plt.ylabel("Number of attacks",fontsize=15)
plt.title("Top 20 Terrorist Group Attacks",fontsize=20)
plt.show()

# %%
Attack = df['Attacktype'].value_counts().drop('Unknown')
print(Attack)
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attacktype, dtype: int64

# %%
plt.figure(figsize=(18,10))
sns.barplot(x=Attack_type.index, y=Attack_type.values, palette='summer')
plt.xticks(rotation = 50,fontsize=12.5)
plt.xlabel("Type of Attack",fontsize=15)
plt.ylabel("Number of attacks",fontsize=15)
plt.title("Top Type of Attacks",fontsize=20)
plt.show()

# %%
Target_data = df['Targettype'].value_counts().nlargest(n=15)
Target_data
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Name: Targettype, dtype: int64

# %%
plt.figure(figsize= (18,10))
sns.barplot(x = Target_data.index , y = Target_data.values, palette='pink')
plt.title('Most Frequent Target Type',fontsize=20)
plt.xlabel('Target Type',fontsize=15)
plt.ylabel('Number of Attacks',fontsize=15)
plt.xticks(rotation = 90, fontsize=12.5)
plt.show()

# %%
Killed = df[['Attacktype','Kill']].groupby(["Attacktype"],axis=0).sum()
Killed
# Out:
#                                          Kill
# Attacktype
# Armed Assault                        160297.0
# Assassination                         24920.0
# Bombing/Explosion                    157321.0
# Facility/Infrastructure Attack         3642.0
# Hijacking                              3718.0
# Hostage Taking (Barricade Incident)    4478.0
# Hostage Taking (Kidnapping)           24231.0
# Unarmed Assault                         880.0
# Unknown                               32381.0

# %%
plt.figure(figsize=(20,10))
sns.barplot(x = Killed.index, y = Killed['Kill'] , palette='autumn')
plt.title("Number of killed ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.xticks(rotation=50, fontsize=10)
plt.show()

# %% [markdown]
# ## Data Analysis and Conclusions

# %%
df=df[['Group','Country','Kill']]
df=df.groupby(['Group','Country'],axis=0).sum().sort_values('Kill',ascending=False).drop('Unknown').reset_index().head(10)
df
# Out:
#                                               Group      Country     Kill
# 0       Islamic State of Iraq and the Levant (ISIL)         Iraq  31058.0
# 1                                           Taliban  Afghanistan  29269.0
# 2                                        Boko Haram      Nigeria  16917.0
# 3                                 Shining Path (SL)         Peru  11595.0
# 4           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 5                                        Al-Shabaab      Somalia   8176.0
# 6  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 7       Islamic State of Iraq and the Levant (ISIL)        Syria   6883.0
# 8                 Nicaraguan Democratic Force (FDN)    Nicaragua   6630.0
# 9                   Tehrik-i-Taliban Pakistan (TTP)     Pakistan   6014.0

# %%
Kill = df.loc[:,'Kill']
print('Number of people killed by terror attack:', int(sum(Kill.dropna())))
# Out:
# Number of people killed by terror attack: 135489

# %%
countryKill = df.pivot_table(columns='Country', values='Kill', aggfunc='sum')
countryKill
# Out:
# Country  Afghanistan  El Salvador     Iraq  Nicaragua  Nigeria  Pakistan  \
# Kill         29269.0       8019.0  31058.0     6630.0  16917.0    6014.0
#
# Country     Peru  Somalia  Sri Lanka   Syria
# Kill     11595.0   8176.0    10928.0  6883.0

# %% [markdown]
# ## Conclusions and Results:
# Country with most attack :Iraq
#
# Cities with most attacks are Baghdad (7589), Karachi (2652), Lima (2359), Mosul (2265) and Belfast (2171)
#
# States with most attacks are Baghdad and Northern Ireland.
#
# Regions with most attacks are Middle East & North Africa (50474), South Asia (44974) and South America (18978).
#
# Year with most attacks is 2014 and Year with the least number of attacks are 1971 and 1973.
#
# Most frequent terrorist groups involved in attacks are Taliban (7478), Islamic State of Iraq and the Levant (ISIL) (5613), Shining Path (SL) (4555) and Farabundo Marti National Liberation Front (FMLN) (3351).
#
# The largest number of attacks are caused by Bombing/Explosion that are 88255
#
# The most harming Attack Type is Armed Assault with 160297.0 casuaslities.
#
# The most vulnerable Target Group is Private Citizens & Property with about 43511 attacks.
#
# ## Security issues and insights derived :
# Since the most frequent Target type is private citizens and properties hence the ones with such characteristics can make sure to have an access of CCTVs and emergency numbers. Provisions must be made for safe abnd easy evacuation in case of an unlikely situation. Private and public spaces must have adequate provisions for the same, such as emergency exits and alarm systems. Frequent evacuation drills and norms and procedures must be carried out.
#
# The most frequent attack found is Bombing/Explosion and this can be decreased if these suppplies are stopped. Various Border Organisations should have a standing corps of 10,000 border guards by 2027 to effectively secure country’s 13,000 km of external land borders and nearly 66,000 km at sea. The new standing corps could, at the request of the country, carry out border control and migration management as well as fight cross-border crime and smuggling of dangerous explosives.
#
# Proper alert in the areas where the explosions are most likely to happen. International Police authorities must be extra vigilant in places with large numbers of people, for example metro and train stations, festivals and concert venues, and shopping centres. A comprehensive action plan defines and determines International Police’s role in the international community’s fight against terrorism.
#
# Governments must support the development of new capabilities and technologies to tackle the terrorist threat and to manage the consequences of a terrorist attack.It must also cooperates with partners and international organisations to leverage the full potential of each stakeholder engaged in the global counter-terrorism effort, in most vulnerable regions like Middle East & North Africa, South Asia and South America.
#
# There must be proper measures to report suspicious situations. Whether or not a situation is suspicious depends very much on the context. For example, an unattended suitcase on a train platform does not necessarily mean anything sinister. Still, the best course of action is to notify a member of staff straight away. Or call the police.
#
# Local Authorities must be responsible of civil security as the local and organisational levels. CCTV Cameras can be used for proper survillemce. Each and every person passing by should be checked with the help of metal etectors etc.Citizens should be alert at their own part too and take responsibility at personal to counter this global threat.
#
# ### References:
#
# https://www.government.nl/topics/counterterrorism-and-national-security/question-and-answer/prevent-a-terrorist-attack
#
# https://www.nato.int/cps/en/natohq/topics_77646.htm
#
# https://www.europarl.europa.eu/news/en/headlines/security/20180316STO99922/how-to-stop-terrorism-eu-measures-explained
